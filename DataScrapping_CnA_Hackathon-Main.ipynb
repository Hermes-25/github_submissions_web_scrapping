# %%
import requests
import pandas as pd
import io
from urllib.parse import urlparse

# Global counter for inaccessible files and valid csv files 
inaccessible_files_count = 0
valid_csv_count = 0

# %%
def get_repo_contents(owner, repo, path="", token=None):
    api_url = f"https://api.github.com/repos/{owner}/{repo}/contents/{path}" #using github api to access public repos
    
    headers = {}  #they are needed to request from api
    if token:
        headers['Authorization'] = f'token {token}'   #if we have token then the authorization header is set 

    response = requests.get(api_url, headers=headers) #sending request to github api to access the contents of the repo
    
    
    print("For URL- ",api_url,"->")
    print(f"Status Code: {response.status_code}\n")
    
    
    if response.status_code == 200: #means it can be accessed 
        return response.json()
    else:
        global inaccessible_files_count
        inaccessible_files_count += 1
        print(f"Failed to retrieve contents. Error: {response.json()}")
        return None

# %%
def validate_csv(file_url):
    response = requests.get(file_url) #response is the requests object that later we convert to string is .text
    if response.status_code == 200:
        df = pd.read_csv(io.StringIO(response.text)) #io.StringIO converts string into an in-memory file object that we reading as csv
        
        # h1n1 and xyz both are valid so -> 
        required_columns_1 = ['respondent_id', 'h1n1_vaccine', 'seasonal_vaccine']
        required_columns_2 = ['respondent_id', 'xyz_vaccine', 'seasonal_vaccine']
        
        if (all(col in df.columns for col in required_columns_1) and len(df.columns) == len(required_columns_1) or all(col in df.columns for col in required_columns_2) and len(df.columns) == len(required_columns_2)):
            
            return df
        else:
            return None
    else:
        return None

# %%
def process_repository(url, criteria, token):
    if not is_github_repo(url):
        return "Invalid GitHub URL"

    # Remove .git extension if present because it was casusing it to not being able to access the URL
    if url.endswith(".git"):
        url = url[:-4]

    # Extract owner and repo from URL
    parts = urlparse(url).path.split('/')
    owner, repo = parts[1], parts[2]

    contents = get_repo_contents(owner, repo, "", token)
    if contents is None:
        return "Unable to access repository contents"

    csv_url = find_any_csv(contents, owner, repo, token)
    if not csv_url:
        return "No CSV file found in the repository"
    
    global valid_csv_count
    valid_csv_count_repo=0
    valid_csv = validate_csv(csv_url)
    if valid_csv is not None:
        valid_csv_count += 1
        valid_csv_count_repo+=1
        valid_csv_df=valid_csv
        repo_name = urlparse(url).path.replace('/', '_')
        valid_csv_df.to_csv(f"{repo_name}.csv", index=False)

    if valid_csv_count_repo > 0:
       
        return f"{valid_csv_count_repo} valid CSV files found in the repository", valid_csv_df
    else:
        return "No valid CSV file found in the repository"
    
    
    valid_csv = validate_csv(csv_url) #checking if the csv file is valid according to the format
    if valid_csv is not None:
        return "Valid CSV file found", valid_csv #prints the valid csv file
    
    else:
        return "No valid CSV file found in the repository", None

# %%
def read_github_links(csv_path):
    df = pd.read_csv(csv_path)
    links = df['GitHub Links'].tolist()  
    return links #list of the all links

# %%
def read_submission_criteria(csv_path):
    criteria_df = pd.read_csv(csv_path)
    # Convert criteria to a dictionary cuz its better to check conditions on
    criteria = criteria_df.to_dict(orient='list')
    return criteria #dictionary that has keys as the columns titles

# %%
def is_github_repo(url):
    parsed_url = urlparse(url)
    return parsed_url.netloc == "github.com" and len(parsed_url.path.split('/')) >= 3

# %%
def get_file_metadata(owner, repo, path, token):
    api_url = f"https://api.github.com/repos/{owner}/{repo}/contents/{path}"
    
    headers = {}
    if token:
        headers['Authorization'] = f'token {token}'
    
    response = requests.get(api_url, headers=headers)
    
    if response.status_code == 200:
        return response.json() #retruns the json response
    else:
        return None

# %%
def get_last_commit_date(owner, repo, path, token):
    api_url = f"https://api.github.com/repos/{owner}/{repo}/commits?path={path}&per_page=1" 
    
    ###
    #&per_page=1 ensures we get the last commit -> usage of the github API
    ###
    
    headers = {}
    if token:
        headers['Authorization'] = f'token {token}'

    response = requests.get(api_url, headers=headers)
    
    if response.status_code == 200:
        commit_data = response.json() #to parse the JSON response to return the data of last commit 
        if commit_data:
            return commit_data[0]['commit']['committer']['date']
    return None

def find_any_csv(contents, owner, repo, token):
    csv_files = []
    for item in contents:
        if item['type'] == 'file' and item['name'].endswith('.csv') and 'training' not in item['name']:
            last_commit_date = get_last_commit_date(owner, repo, item['path'], token)
            if last_commit_date:
                item['last_commit_date'] = last_commit_date
                csv_files.append(item)
        elif item['type'] == 'dir':
            dir_contents = get_repo_contents(owner, repo, item['path'], token)
            if dir_contents is not None:
                result = find_any_csv(dir_contents, owner, repo, token)
                if result is not None:
                    csv_files.extend(result)
    
    if csv_files:
        csv_files = [file for file in csv_files if 'last_commit_date' in file]
        if not csv_files:
            return None
        # Sort by last_commit_date and return the most recent CSV file url
        
        csv_files.sort(key=lambda x: x['last_commit_date'], reverse=True)
        return csv_files[0]['download_url']
    
    return None

# %%
# commit_data:
# This variable holds the JSON data returned from the GitHub API endpoint after requesting commit information. 
#It represents an array (list) of commit objects.

# commit_data[0]:
# Accesses the first (most recent) commit object in the commit_data array. 
#GitHub API returns commit objects sorted by the commit date in descending order by default when using per_page=1.

# commit_data[0]['commit']:
# Within the first commit object (commit_data[0]), accesses the nested commit object. 
#This object contains detailed information about the commit itself, such as the commit message, author details, and committer details.

# commit_data[0]['commit']['committer']:
# Inside the commit object, accesses the committer field. 
#The committer field contains information about the person who applied the commit to the repository 
#This includes details such as the name, email, and date of the committer.

# commit_data[0]['commit']['committer']['date']:
# Finally, accesses the date field within the committer object. 
#This field specifically contains the date and time when the commit was made.

# %%
def main(github_links_path, criteria_path, token):
    global inaccessible_files_count,valid_csv_count

    inaccessible_files_count = 0

    valid_csv_count=0
    # Read GitHub links and submission criteria from CSV
    github_links = read_github_links(github_links_path) #list
    criteria = read_submission_criteria(criteria_path) #dictionary

    results = []
    for url in github_links:
        result = process_repository(url, criteria, token)
        results.append((url, result))

    for url, result in results:
        if isinstance(result, pd.DataFrame):
            print(f"Valid CSV file found for {url}:")
            print(result)
        else:
            print(f"{url}: {result}")

    # Print the count of inaccessible files
    print(f"Number of repositories that couldn't be accessed: {inaccessible_files_count}")
    print(f"Number of valid csv files : {valid_csv_count}")


if __name__ == "__main__":
    github_links_path = "links_of_submission.csv" 
    criteria_path = "submission_format.csv" 
    token = #hidden#  # GitHub personal access token 

    main(github_links_path, criteria_path, token)
# Out:
# For URL-  https://api.github.com/repos/ASNR1010/Hack-a-thon-DataHack-by-IIT-Guwahati/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/gursharankaur13/Summer-Analytics-2024/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/gursharankaur13/Summer-Analytics-2024/contents/Week 3 Hackathon ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/gursharankaur13/Summer-Analytics-2024/contents/Week 3 Hackathon/ Solution ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/gursharankaur13/Summer-Analytics-2024/contents/Week 3 Hackathon/Datasets ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/gursharankaur13/Summer-Analytics-2024/contents/Week 3 Hackathon/Output ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/jigs-bot/GFG_DataHack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/IISHITA-BANERJEE/-IISHITABANERJEE-_Datahack-/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/iam-venkat03/gfg_datahackathon_iitg/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/rishabhluwang/RishabhSingha_Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/utsavhingar22/DataHack--Summer-Analytics-2024-IITG-CAC/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/utsavhingar22/DataHack--Summer-Analytics-2024-IITG-CAC/contents/dataset and all ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/paras28-05/Summer_analytic_program/contents/ ->
# Status Code: 404
#
# Failed to retrieve contents. Error: {'message': 'Not Found', 'documentation_url': 'https://docs.github.com/rest/repos/contents#get-repository-content', 'status': '404'}
# For URL-  https://api.github.com/repos/subhadipgit07/Vaccine_Data_Hackacthon/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/saarthak5/Summer-Analytics-Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/saarthak5/Summer-Analytics-Datahack/contents/datasets ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Ankush142930/DataHack_Solution/contents/ ->
# Status Code: 404
#
# Failed to retrieve contents. Error: {'message': 'Not Found', 'documentation_url': 'https://docs.github.com/rest/repos/contents#get-repository-content', 'status': '404'}
# For URL-  https://api.github.com/repos/Dh1962/GFGHackathon_sa/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/cateto56/Hackathon/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/gunajakku/Logistic_reg_fail/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/LittleJoeHarp/HACKATHON_1/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/AyushIsOn/AyushGupta_Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Aditya0300/hackathonsubmit/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/ItzRangan/DataHack_IITG/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Amit-Ghoslya/DataHack-by-IIT-Guwahati/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/deltaparticle/CNA_Hackathon/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Starkdoorstep12/Hackathon_sklearn/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/amoghkapoor/datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/YashRajSingh1001/Recipe-for-Rating/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Nihal606/Nihal_kumar_Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/bytefoot/SummerAnalyticsHackathon/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/SKed72274/Subhashree_Kedia_Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/BuddyBoy26/Pritvik_Datahack/contents/ ->
# Status Code: 404
#
# Failed to retrieve contents. Error: {'message': 'Not Found', 'documentation_url': 'https://docs.github.com/rest/repos/contents#get-repository-content', 'status': '404'}
# For URL-  https://api.github.com/repos/ayushiGautam-0110/hackathon/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Dibya-ranjan-samal/DibyaRanjanSamal_Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/UTSAVS26/DataHack-by-IIT-Guwahati/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/UTSAVS26/DataHack-by-IIT-Guwahati/contents/dataset ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/DataWorshipper/demos/contents/ ->
# Status Code: 404
#
# Failed to retrieve contents. Error: {'message': 'Not Found', 'documentation_url': 'https://docs.github.com/rest/repos/contents#get-repository-content', 'status': '404'}
# For URL-  https://api.github.com/repos/RaunakSeksaria/Summer_h1/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/blankba/VaccinePredictor/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/123suraj-sky/DataHack-by-IIT-Guwahati/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/123suraj-sky/DataHack-by-IIT-Guwahati/contents/data ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Aviral1611/IIt_guhawati_data_analytics/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Shubham-7505/Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/prishant/Rishant-Pal_Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/prishant/Rishant-Pal_Datahack/contents/data_preprocess ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/NarenSchinora/Predictions_naive_bayes/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Mkaif-Qureshi/Summer-Analytics-IITG/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Mkaif-Qureshi/Summer-Analytics-IITG/contents/Hackathon ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Mkaif-Qureshi/Summer-Analytics-IITG/contents/Notebooks ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Mkaif-Qureshi/Summer-Analytics-IITG/contents/Week 1 ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Mkaif-Qureshi/Summer-Analytics-IITG/contents/Week 2 ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Mkaif-Qureshi/Summer-Analytics-IITG/contents/Week 4 ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/shubhamkkgp/Shubham_Kumar_Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/PushkarThapar/PushkarThapar_Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/YashShivhare007/Yash_Shivhare_Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Alokkr00/Hackathon/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/mahelika/VaccineProbabilityPredictor_DataHack-by-IIT-Guwahati/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/nsain25/Nandini_Sain_Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/SanthoshToorpu/Summer-analytics-sub/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Pranjali6/Pranjali_Sharma_DataHack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/akshatsinha744/Summer_Analytics_IIT_Guwahati/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Manshi34-github/Manshi_Kumari_Datahack-24_IIT_Guwahati/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/ShubhaSwarup/DataHack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/ShubhaSwarup/DataHack/contents/DataHack_dataset ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/BadaamPista/DataHack-by-IIT-Guwahati/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/smoothcoder64/ArunavaBhattacharya_Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/7wik3vedi16/DataHack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Chinthan07/Vaccine_Dataset_Solution/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/deepak3726/Deepak-classification-problem/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/rayaankhan/DataHack-by-IIT-Guwahati-GFG-24/contents/ ->
# Status Code: 200
# For URL-  https://api.github.com/repos/rayaankhan/DataHack-by-IIT-Guwahati-GFG-24/contents/data ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/chanda-yeswanthreddy/Multilabel_Classification/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/DiyaPrasad2002/Vaccine-Prediction/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sharvilkothari/Sharvil_Kothari_DataHack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/kanishka73/Hackhathon-iit-guhwati-gfg/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/FlyingDragon112/ArnavAgarwal_DataHack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/bhaskar101010/Probability-Prediction-of-two-vaccines-labels/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Saksh8/Aastha_Ojha_DataHack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Soumyadeep8016/Soumya_datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/khushigit15/Khushi_DataHack/contents/ ->
# Status Code: 404
#
# Failed to retrieve contents. Error: {'message': 'Not Found', 'documentation_url': 'https://docs.github.com/rest/repos/contents#get-repository-content', 'status': '404'}
# For URL-  https://api.github.com/repos/naina123k/Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/PrakhyatVerma/hackathon/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/awivawie/hkthnpart/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/awivawie/hkthnpart/contents/dataset and all ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/AmanRaj2002/Aman_Raj_Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Rhythm-Gubrani/Rhythm_DataHack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Rhythm-Gubrani/Rhythm_DataHack/contents/dataset ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Mr-Khandelwal/Rajat_Khandelwal_DataHack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Mr-Khandelwal/Rajat_Khandelwal_DataHack/contents/dataset ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/anuj-kasera/DataHack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/AnushkaGuptaa/Anushka_Gupta_DataHack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/singhapeksha/data_hack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/VeryVarg/IITG/contents/ ->
# Status Code: 404
#
# Failed to retrieve contents. Error: {'message': 'Not Found', 'documentation_url': 'https://docs.github.com/rest/repos/contents#get-repository-content', 'status': '404'}
# For URL-  https://api.github.com/repos/darkfan-tasy/Summer-Analytics-2024/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Balaji20042008/Hackathon/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Mridhubashini/mridhubashini_datahack/contents/ ->
# Status Code: 404
#
# Failed to retrieve contents. Error: {'message': 'Not Found', 'documentation_url': 'https://docs.github.com/rest/repos/contents#get-repository-content', 'status': '404'}
# For URL-  https://api.github.com/repos/Ayushs2/Datahack-byIITG/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/mohammed-khaleel/vaccine_prediction/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/manishka28/Summer-Analytics-DataHack-by-IIT-Guwahati/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Ikshvaku24/caiitg_datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Gourav-IITR/submission_iitg_cac_hackathon_1/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/VARUN3WARE/hackathon/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/tarun-009/Tarun_Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/pranjal3060/PranjalSingh_Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/rohitfeed28/amarjeet_datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/RathodShivaKumar/DataHack_IITG/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/nityachandna/NityaChandna_DataHack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Narasimhan-G/DataHack-by-IIT-Guwahati-and-Geeks-for-Geeks/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/raman0712/Raman_DataHack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/atharva-mandar-phatak/Datahack-2024/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/TejasOJ/Hackathon_GFG/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/MirMaiti/Mir_Maiti_Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Sharvil14/Hackathon-IITG/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Guava001/IIT-Guwahati-hackathon/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/mahathaankitkumar/Hackathon/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/GautamJetley/DataHack-Submission/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Roopam-kapoor/summer_analytics/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/preethipinninti/summer_analytics_hackathon/contents/ ->
# Status Code: 404
#
# Failed to retrieve contents. Error: {'message': 'Not Found', 'documentation_url': 'https://docs.github.com/rest/repos/contents#get-repository-content', 'status': '404'}
# For URL-  https://api.github.com/repos/Madhumasa84/ai-ml-project/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Shivaraj-R-Kolli/ShivarajRKolli_Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/HackathonsCompeted/DataHack-by-IIT-guwahati/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/HackathonsCompeted/DataHack-by-IIT-guwahati/contents/dataset ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/HackathonsCompeted/DataHack-by-IIT-guwahati/contents/dataset/.ipynb_checkpoints ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Chirag-Punia/dataHack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/manojbamniya/Manoj_Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/kaamu1/kaminiDataHackathon/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/iampritam123/pritam_DataHack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Yatendrarajput/YatendraRajput_Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Yatendrarajput/YatendraRajput_Datahack/contents/.ipynb_checkpoints ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Palakjhamnani/Palak_jhamnani_Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/vimlesh9iitd/IITG-HACKATHON/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/kumar1607/IIT-Guwahati-SUMMER-ANALYTICS-2024/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Avijit2103/data_hack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/tunirwabhitkar/DataHack-by-IIT-Guwahati/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/AmanAg744/CAIITG_SA24_hackathon/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Arjun5421/DataHack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/ojomg/DataHack-by-IIT-Guwahati/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/NainishKumar/Nainish_Kumar_Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/namannasra/Naman-Harish-Nasra_Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/REDFLAG-bugs/Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/REDFLAG-bugs/Datahack/contents/dataset and all ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/InternKaChoda/submission_format/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Anisha0101/Analytics-Hackathon/contents/ ->
# Status Code: 200
# For URL-  https://api.github.com/repos/Keshav-1729/DataHack_SA2024/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Keshav-1729/DataHack_SA2024/contents/Seasonal ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Keshav-1729/DataHack_SA2024/contents/xyz ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/therahulgithub/RahulKumar_Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/swaralipi04/SwaralipiDatta_Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/T-arn21/ArnavTiku_Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Reboot2004/DataHack-Submission_2/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/SketchyCarrot/DataHack_by_IITG/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/himani2853/project_datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/himani2853/project_datahack/contents/hackathon ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Abhay04ch/DataHack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Arka-Mishra/Arka-Prava-Mishra_DataHack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/asquare004/DataHack-2024-by-IIT-Guwahati/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/asquare004/DataHack-2024-by-IIT-Guwahati/contents/dataset ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/AmanTasiwal/Flu_Vaccine_Prediction/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/AgrawalAryan/AACreates/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/divyatapandey/DivyataPandey_Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/divyatapandey/DivyataPandey_Datahack/contents/.ipynb_checkpoints ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/divyatapandey/DivyataPandey_Datahack/contents/dataset and all ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Gaurav45Kumar/Gaurav-Kumar_Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Abhi24iitg/Summer_analytics_hackathon/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Abhi24iitg/Summer_analytics_hackathon/contents/.ipynb_checkpoints ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Mohit-Khirwar/DataHack-by-IIT-Guwahati/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/ADI-NARAYAN27/Aditya_Narayan_DataHack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/ADI-NARAYAN27/Aditya_Narayan_DataHack/contents/Dataset and All ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Shikh-Bharti/-Shikha-Bharti-_Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Vineet-Jagga/Vineet_Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/JATIN-IITR/Prediction-of-Vaccine-uptake-Summer-Analytics-2024-/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/anirudhxchaturvedi/Anirudh_Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/anirudhxchaturvedi/Anirudh_Datahack/contents/ML_project ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/tara210/TaraRamasamy_datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/aygayush/gfgprojectbyayushgupta/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/apurv-001/Data-Science/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Navya-Verma11/DataHack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/knithinsankar-01/DataHack_Hackthon/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Rajat-mikey/Predicting-probabilities-of-getting-vaccinated/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/manojxplores/dataHack_submission/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/manojxplores/dataHack_submission/contents/hackathon ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/manojxplores/dataHack_submission/contents/hackathon/.ipynb_checkpoints ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Nityam2004/Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/mayank-dahotre/Mayank-Dahotre_Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/abhiswami123/Vaccine-Probability-Prediction/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/akshayc1a/DataHack-by-IIT-Guwahati/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/architbharani/Archit_Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/RohitVarmaSixtyFive/rohit_varma_Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/YawarAman/project-Gulyawar-Aman-_Datahack/contents/ ->
# Status Code: 404
#
# Failed to retrieve contents. Error: {'message': 'Not Found', 'documentation_url': 'https://docs.github.com/rest/repos/contents#get-repository-content', 'status': '404'}
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/.ipynb_checkpoints ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/Data ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/Scripts ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/Scripts/__pycache__ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/etc ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/etc/jupyter ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/etc/jupyter/jupyter_notebook_config.d ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/etc/jupyter/jupyter_server_config.d ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/etc/jupyter/labconfig ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/etc/jupyter/nbconfig ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/etc/jupyter/nbconfig/notebook.d ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/applications ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/icons ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/icons/hicolor ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/icons/hicolor/scalable ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/icons/hicolor/scalable/apps ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/kernels ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/kernels/python3 ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/schemas ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/schemas/@jupyter-notebook ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/schemas/@jupyter-notebook/application-extension ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/schemas/@jupyter-notebook/documentsearch-extension ->
# Status Code: 200
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/schemas/@jupyter-notebook/help-extension ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/schemas/@jupyter-notebook/notebook-extension ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/schemas/@jupyter-notebook/tree-extension ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/schemas/@jupyterlab ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/schemas/@jupyterlab/application-extension ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/schemas/@jupyterlab/apputils-extension ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/schemas/@jupyterlab/cell-toolbar-extension ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/schemas/@jupyterlab/celltags-extension ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/schemas/@jupyterlab/codemirror-extension ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/schemas/@jupyterlab/completer-extension ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/schemas/@jupyterlab/console-extension ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/schemas/@jupyterlab/csvviewer-extension ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/schemas/@jupyterlab/debugger-extension ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/schemas/@jupyterlab/docmanager-extension ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/schemas/@jupyterlab/documentsearch-extension ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/schemas/@jupyterlab/extensionmanager-extension ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/schemas/@jupyterlab/filebrowser-extension ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/schemas/@jupyterlab/fileeditor-extension ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/schemas/@jupyterlab/help-extension ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/schemas/@jupyterlab/htmlviewer-extension ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/schemas/@jupyterlab/hub-extension ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/schemas/@jupyterlab/imageviewer-extension ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/schemas/@jupyterlab/inspector-extension ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/schemas/@jupyterlab/launcher-extension ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/schemas/@jupyterlab/logconsole-extension ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/schemas/@jupyterlab/lsp-extension ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/schemas/@jupyterlab/mainmenu-extension ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/schemas/@jupyterlab/markdownviewer-extension ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/schemas/@jupyterlab/mathjax-extension ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/schemas/@jupyterlab/metadataform-extension ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/schemas/@jupyterlab/notebook-extension ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/schemas/@jupyterlab/running-extension ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/schemas/@jupyterlab/settingeditor-extension ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/schemas/@jupyterlab/shortcuts-extension ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/schemas/@jupyterlab/statusbar-extension ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/schemas/@jupyterlab/terminal-extension ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/schemas/@jupyterlab/toc-extension ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/schemas/@jupyterlab/tooltip-extension ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/schemas/@jupyterlab/translation-extension ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/schemas/@jupyterlab/workspaces-extension ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/static ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/themes ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/themes/@jupyterlab ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/themes/@jupyterlab/theme-dark-extension ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/themes/@jupyterlab/theme-dark-high-contrast-extension ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/lab/themes/@jupyterlab/theme-light-extension ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/labextensions ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/labextensions/@jupyter-notebook ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/labextensions/@jupyter-notebook/lab-extension ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/labextensions/@jupyter-notebook/lab-extension/schemas ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/labextensions/@jupyter-notebook/lab-extension/schemas/@jupyter-notebook ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/labextensions/@jupyter-notebook/lab-extension/schemas/@jupyter-notebook/lab-extension ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/labextensions/@jupyter-notebook/lab-extension/static ->
# Status Code: 200
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/labextensions/@jupyter-widgets ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/labextensions/@jupyter-widgets/jupyterlab-manager ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/labextensions/@jupyter-widgets/jupyterlab-manager/schemas ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/labextensions/@jupyter-widgets/jupyterlab-manager/schemas/@jupyter-widgets ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/labextensions/@jupyter-widgets/jupyterlab-manager/schemas/@jupyter-widgets/jupyterlab-manager ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/labextensions/@jupyter-widgets/jupyterlab-manager/static ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/labextensions/jupyterlab_pygments ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/labextensions/jupyterlab_pygments/static ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/nbconvert ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/nbconvert/templates ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/nbconvert/templates/asciidoc ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/nbconvert/templates/base ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/nbconvert/templates/basic ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/nbconvert/templates/classic ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/nbconvert/templates/classic/static ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/nbconvert/templates/compatibility ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/nbconvert/templates/lab ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/nbconvert/templates/lab/static ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/nbconvert/templates/latex ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/nbconvert/templates/markdown ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/nbconvert/templates/python ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/nbconvert/templates/reveal ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/nbconvert/templates/reveal/static ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/nbconvert/templates/rst ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/nbconvert/templates/script ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/nbconvert/templates/webpdf ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/nbextensions ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/jupyter/nbextensions/jupyter-js-widgets ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/man ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha345trip/Vaccine-Prediction/contents/share/man/man1 ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/rushi-k12/-Rushikesh_Kusuma-_Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/abhay5802/Abhay_Dataheck/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/DishantB0411/Dishant_Bothra_Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/DishantB0411/Dishant_Bothra_Datahack/contents/dataset and all ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Priyanshu7129/seasonal_flu-vaccine/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/GunjitCodes/DataHack-IIT-Guwahati/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/ICareEvents/SummerAnalytics/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/mayankmittal29/VaccineClassifier/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/kunalsingh1301/vaaciantion/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Dhivyaindhu/Hackthon_GeeksforGeeks/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/RamanGuduru/Guduru_V_N_S_Ganesh_Raman_Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Aanchal2707/Aanchal_datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/AathiTira/AathithyaTiraviamS_Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/aryan2702p/AryanPatel_Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/aryan2702p/AryanPatel_Datahack/contents/customer-retention-analysis-prediction ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sc941432/The-DataHack-IIT-Guwahati/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Prachijha1/Prachi_jha-Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/harshsrivastava321/Summer-Analytics2024/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Meghana242004/summeranalyticsiitg/contents/ ->
# Status Code: 404
#
# Failed to retrieve contents. Error: {'message': 'Not Found', 'documentation_url': 'https://docs.github.com/rest/repos/contents#get-repository-content', 'status': '404'}
# For URL-  https://api.github.com/repos/karthik7271/Karthik_Ragulan_DataHack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/ayerhssb/vaccine-prediction/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha-shanks/DataHack_submission/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/sha-shanks/DataHack_submission/contents/.ipynb_checkpoints ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/lokaesshwar/Lokaesshwar-S_DataHack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Sumit10987/DATAHACKATHON_Sumit/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/adithya9966/LEETCODE/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Cvssvay/Data_Analytics_HackaThon/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/keshavmarian/Hack-a-thon-DataHack-by-IIT-Guwahati-Powered-By-GeeksforGeeks/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/keshavmarian/Hack-a-thon-DataHack-by-IIT-Guwahati-Powered-By-GeeksforGeeks/contents/Dataset ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/DhineshKaviraaj/SummerAnalytics-Week3/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Pratham-afk/pratham_pansari_Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Anshuljain22/Summer-Analytics/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/INam1995/Inam_Yadav_Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/INam1995/Inam_Yadav_Datahack/contents/Dataset ->
# Status Code: 200
# For URL-  https://api.github.com/repos/Keerthan-Shenoy/KEERTHANSHENOY_Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Sourajjal/Summer-Analytics-DataHack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/ArranabManhas/Data_hack_project/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/HARSHITH-MANDLI/M.V.S.Harshith_Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Anushika0601/Anushika_Srivastava_DataHack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/madhu04075/Datahack_1/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/Manas8953/Project/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/swatiswapna/swati_swapna_Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/swatiswapna/swati_swapna_Datahack/contents/dataset ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/suchiagarwal23/Suchi_Agarwal_Datahack/contents/ ->
# Status Code: 200
#
# For URL-  https://api.github.com/repos/svunofficial/Shivashish_DataHack/contents/ ->
# Status Code: 200
#
# https://github.com/ASNR1010/Hack-a-thon-DataHack-by-IIT-Guwahati: ('1 valid CSV files found in the repository',        respondent_id  xyz_vaccine  seasonal_vaccine
# 0              26707         0.16              0.30
# 1              26708         0.05              0.02
# 2              26709         0.44              0.79
# 3              26710         0.69              0.85
# 4              26711         0.20              0.43
# ...              ...          ...               ...
# 26703          53410         0.30              0.52
# 26704          53411         0.17              0.34
# 26705          53412         0.09              0.31
# 26706          53413         0.08              0.38
# 26707          53414         0.53              0.55
#
# [26708 rows x 3 columns])
# https://github.com/gursharankaur13/Summer-Analytics-2024/tree/main/Week%203%20Hackathon: No CSV file found in the repository
# https://github.com/jigs-bot/GFG_DataHack: ('1 valid CSV files found in the repository',       respondent_id  xyz_vaccine  seasonal_vaccine
# 0             15772     0.092057          0.388157
# 1              9407     0.072949          0.301744
# 2             16515     0.262635          0.806180
# 3             23353     0.151150          0.160340
# 4             10008     0.028402          0.204956
# ...             ...          ...               ...
# 2666          24365     0.355970          0.547587
# 2667          11773     0.071322          0.392824
# 2668          24273     0.135340          0.175369
# 2669          12908     0.223700          0.683542
# 2670          11715     0.105732          0.723039
#
# [2671 rows x 3 columns])
# https://github.com/IISHITA-BANERJEE/-IISHITABANERJEE-_Datahack-: ('1 valid CSV files found in the repository',        respondent_id  xyz_vaccine  seasonal_vaccine
# 0              26707         0.17              0.40
# 1              26708         0.03              0.03
# 2              26709         0.31              0.72
# 3              26710         0.62              0.87
# 4              26711         0.30              0.46
# ...              ...          ...               ...
# 26703          53410         0.14              0.52
# 26704          53411         0.22              0.34
# 26705          53412         0.15              0.44
# 26706          53413         0.06              0.39
# 26707          53414         0.54              0.65
#
# [26708 rows x 3 columns])
# https://github.com/iam-venkat03/gfg_datahackathon_iitg: No CSV file found in the repository
# https://github.com/rishabhluwang/RishabhSingha_Datahack.git: ('1 valid CSV files found in the repository',        respondent_id  h1n1_vaccine  seasonal_vaccine
# 0              26707           0.5               0.7
# 1              26708           0.5               0.7
# 2              26709           0.5               0.7
# 3              26710           0.5               0.7
# 4              26711           0.5               0.7
# ...              ...           ...               ...
# 26703          53410           0.5               0.7
# 26704          53411           0.5               0.7
# 26705          53412           0.5               0.7
# 26706          53413           0.5               0.7
# 26707          53414           0.5               0.7
#
# [26708 rows x 3 columns])
# https://github.com/utsavhingar22/DataHack--Summer-Analytics-2024-IITG-CAC: No valid CSV file found in the repository
# https://github.com/paras28-05/Summer_analytic_program: Unable to access repository contents
# https://github.com/subhadipgit07/Vaccine_Data_Hackacthon.git: ('1 valid CSV files found in the repository',        respondent_id  xyz_vaccine  seasonal_vaccine
# 0              26707         0.08              0.21
# 1              26708         0.05              0.04
# 2              26709         0.45              0.73
# 3              26710         0.47              0.88
# 4              26711         0.23              0.53
# ...              ...          ...               ...
# 26703          53410         0.34              0.52
# 26704          53411         0.09              0.21
# 26705          53412         0.14              0.21
# 26706          53413         0.05              0.43
# 26707          53414         0.54              0.56
#
# [26708 rows x 3 columns])
# https://github.com/saarthak5/Summer-Analytics-Datahack: ('1 valid CSV files found in the repository',        xyz_vaccine  seasonal_vaccine  respondent_id
# 0         0.699557          0.647198          26707
# 1         0.875399          0.595006          26708
# 2         0.798516          0.147885          26709
# 3         0.211783          0.275804          26710
# 4         0.280525          0.875089          26711
# ...            ...               ...            ...
# 26703     0.749697          0.442189          53410
# 26704     0.328890          0.379654          53411
# 26705     0.314004          0.708911          53412
# 26706     0.028327          0.377014          53413
# 26707     0.464757          0.196818          53414
#
# [26708 rows x 3 columns])
# https://github.com/Ankush142930/DataHack_Solution: Unable to access repository contents
# https://github.com/Dh1962/GFGHackathon_sa: ('1 valid CSV files found in the repository',        respondent_id  xyz_vaccine  seasonal_vaccine
# 0                  0     0.087269          0.015219
# 1                  1     0.157466          0.433325
# 2                  2     0.221140          0.225126
# 3                  3     0.606121          0.108833
# 4                  4     0.116442          0.100787
# ...              ...          ...               ...
# ...
#
# [26708 rows x 3 columns])
# https://github.com/AathiTira/AathithyaTiraviamS_Datahack: ('1 valid CSV files found in the repository',        respondent_id  xyz_vaccine  seasonal_vaccine
# 0              26707     0.060000          0.390000
# 1              26708     0.060000          0.220000
# 2              26709     0.155833          0.283333
# 3              26710     0.381511          0.987939
# 4              26711     0.270000          0.262500
# ...              ...          ...               ...
# 26703          53410     0.149996          0.320311
# 26704          53411     0.220000          0.190000
# 26705          53412     0.610048          0.630048
# 26706          53413     0.597331          0.786140
# 26707          53414     0.190000          0.280000
#
# [26708 rows x 3 columns])
# https://github.com/aryan2702p/AryanPatel_Datahack: No CSV file found in the repository
# https://github.com/sc941432/The-DataHack-IIT-Guwahati.git: ('1 valid CSV files found in the repository',        respondent_id  xyz_vaccine  seasonal_vaccine
# 0              26707         0.16              0.31
# 1              26708         0.05              0.07
# 2              26709         0.51              0.74
# 3              26710         0.54              0.91
# 4              26711         0.23              0.49
# ...              ...          ...               ...
# 26703          53410         0.32              0.42
# 26704          53411         0.28              0.35
# 26705          53412         0.05              0.30
# 26706          53413         0.08              0.40
# 26707          53414         0.42              0.67
#
# [26708 rows x 3 columns])
# https://github.com/Prachijha1/Prachi_jha-Datahack: ('1 valid CSV files found in the repository',        respondent_id  xyz_vaccine  seasonal_vaccine
# 0              26707          0.2               0.3
# 1              26708          0.2               0.1
# 2              26709          0.4               0.7
# 3              26710          0.6               0.8
# 4              26711          0.3               0.4
# ...              ...          ...               ...
# 26703          53410          0.3               0.5
# 26704          53411          0.2               0.3
# 26705          53412          0.2               0.4
# 26706          53413          0.2               0.4
# 26707          53414          0.4               0.5
#
# [26708 rows x 3 columns])
# https://github.com/harshsrivastava321/Summer-Analytics2024: ('1 valid CSV files found in the repository',        respondent_id  xyz_vaccine  seasonal_vaccine
# 0           1.732116     0.215261          0.108495
# 1           1.732245     0.010195          0.013591
# 2           1.732375     0.169996          0.798705
# 3           1.732505     0.785631          0.955088
# 4           1.732634     0.330983          0.566588
# ...              ...          ...               ...
# 26703       5.195698     0.184873          0.581421
# 26704       5.195828     0.231326          0.069766
# 26705       5.195958     0.070202          0.326785
# 26706       5.196088     0.004600          0.293340
# 26707       5.196217     0.648299          0.673349
#
# [26708 rows x 3 columns])
# https://github.com/Meghana242004/summeranalyticsiitg: Unable to access repository contents
# https://github.com/karthik7271/Karthik_Ragulan_DataHack: No valid CSV file found in the repository
# https://github.com/ayerhssb/vaccine-prediction: No CSV file found in the repository
# https://github.com/sha-shanks/DataHack_submission: ('1 valid CSV files found in the repository',        respondent_id  h1n1_vaccine  seasonal_vaccine
# 0              26707      0.056441          0.295661
# 1              26708      0.048056          0.045246
# 2              26709      0.433710          0.582613
# 3              26710      0.497196          0.881339
# 4              26711      0.162161          0.465798
# ...              ...           ...               ...
# 26703          53410      0.341929          0.520766
# 26704          53411      0.101576          0.281851
# 26705          53412      0.134227          0.198199
# 26706          53413      0.062279          0.368330
# 26707          53414      0.585077          0.528400
#
# [26708 rows x 3 columns])
# https://github.com/lokaesshwar/Lokaesshwar-S_DataHack: ('1 valid CSV files found in the repository',        respondent_id  xyz_vaccine  seasonal_vaccine
# 0              26707     0.056967          0.310921
# 1              26708     0.020092          0.038579
# 2              26709     0.381192          0.509423
# 3              26710     0.511116          0.873881
# 4              26711     0.169427          0.458496
# ...              ...          ...               ...
# 26703          53410     0.300444          0.468646
# 26704          53411     0.042686          0.234056
# 26705          53412     0.158282          0.205361
# 26706          53413     0.056982          0.347005
# 26707          53414     0.596570          0.502765
#
# [26708 rows x 3 columns])
# https://github.com/Sumit10987/DATAHACKATHON_Sumit: No valid CSV file found in the repository
# https://github.com/adithya9966/LEETCODE: No CSV file found in the repository
# https://github.com/Cvssvay/Data_Analytics_HackaThon.git: ('1 valid CSV files found in the repository',        respondent_id  xyz_vaccine  seasonal_vaccine
# 0              26707     0.033651          0.077391
# 1              26708     0.015161          0.013234
# 2              26709     0.229374          0.275898
# 3              26710     0.564942          0.978360
# 4              26711     0.211314          0.431995
# ...              ...          ...               ...
# 26703          53410     0.166031          0.349265
# 26704          53411     0.141344          0.049243
# 26705          53412     0.101679          0.265341
# 26706          53413     0.255551          0.750829
# 26707          53414     0.254409          0.462699
#
# [26708 rows x 3 columns])
# https://github.com/keshavmarian/Hack-a-thon-DataHack-by-IIT-Guwahati-Powered-By-GeeksforGeeks: ('1 valid CSV files found in the repository',        respondent_id  xyz_vaccine  seasonal_vaccine
# 0              26707         0.25              0.30
# 1              26708         0.06              0.03
# 2              26709         0.49              0.81
# 3              26710         0.44              0.89
# 4              26711         0.23              0.49
# ...              ...          ...               ...
# 26703          53410         0.31              0.53
# 26704          53411         0.23              0.29
# 26705          53412         0.15              0.37
# 26706          53413         0.09              0.33
# 26707          53414         0.45              0.56
#
# [26708 rows x 3 columns])
# https://github.com/DhineshKaviraaj/SummerAnalytics-Week3: ('1 valid CSV files found in the repository',        respondent_id  xyz_vaccine  seasonal_vaccine
# 0                  0         0.15              0.34
# 1                  1         0.05              0.09
# 2                  2         0.62              0.83
# 3                  3         0.26              0.76
# 4                  4         0.27              0.54
# ...              ...          ...               ...
# 26703          26703         0.13              0.48
# 26704          26704         0.26              0.26
# 26705          26705         0.10              0.33
# 26706          26706         0.14              0.39
# 26707          26707         0.31              0.54
#
# [26708 rows x 3 columns])
# https://github.com/Pratham-afk/pratham_pansari_Datahack: No valid CSV file found in the repository
# https://github.com/Anshuljain22/Summer-Analytics.git: ('1 valid CSV files found in the repository',        respondent_id  xyz_vaccine  seasonal_vaccine
# 0              26707     0.055493          0.292756
# 1              26708     0.046944          0.045287
# 2              26709     0.411132          0.589987
# 3              26710     0.498633          0.880806
# 4              26711     0.162650          0.469046
# ...              ...          ...               ...
# 26703          53410     0.344922          0.535323
# 26704          53411     0.102749          0.284877
# 26705          53412     0.134373          0.198811
# 26706          53413     0.061987          0.368459
# 26707          53414     0.587569          0.539277
#
# [26708 rows x 3 columns])
# https://github.com/INam1995/Inam_Yadav_Datahack: ('1 valid CSV files found in the repository',        respondent_id  xyz_vaccine  seasonal_vaccine
# 0                  0         0.30              0.35
# 1                  1         0.06              0.11
# 2                  2         0.29              0.72
# 3                  3         0.55              0.87
# 4                  4         0.34              0.49
# ...              ...          ...               ...
# 26703          26703         0.14              0.43
# 26704          26704         0.21              0.37
# 26705          26705         0.16              0.17
# 26706          26706         0.11              0.38
# 26707          26707         0.50              0.59
#
# [26708 rows x 3 columns])
# https://github.com/Keerthan-Shenoy/KEERTHANSHENOY_Datahack: ('1 valid CSV files found in the repository',        respondent_id  h1n1_vaccine  seasonal_vaccine
# 0              26707          0.11              0.16
# 1              26708          0.06              0.02
# 2              26709          0.59              0.88
# 3              26710          0.55              0.83
# 4              26711          0.25              0.48
# ...              ...           ...               ...
# 26703          53410          0.31              0.46
# 26704          53411          0.17              0.41
# 26705          53412          0.10              0.33
# 26706          53413          0.06              0.45
# 26707          53414          0.38              0.61
#
# [26708 rows x 3 columns])
# https://github.com/Sourajjal/Summer-Analytics-DataHack: ('1 valid CSV files found in the repository',        respondent_id  h1n1_vaccine  seasonal_vaccine
# 0              26707      0.126192          0.378692
# 1              26708      0.126192          0.378692
# 2              26709      0.183165          0.348144
# 3              26710      0.212795          0.549528
# 4              26711      0.393013          0.630780
# ...              ...           ...               ...
# 26703          53410      0.180584          0.383734
# 26704          53411      0.393013          0.630780
# 26705          53412      0.212795          0.549528
# 26706          53413      0.242021          0.599796
# 26707          53414      0.202634          0.522068
#
# [26708 rows x 3 columns])
# https://github.com/ArranabManhas/Data_hack_project: ('1 valid CSV files found in the repository',        respondent_id  xyz_vaccine  seasonal_vaccine
# 0              26707     0.112170          0.207390
# 1              26708     0.013824          0.049247
# 2              26709     0.515460          0.832906
# 3              26710     0.629498          0.862487
# 4              26711     0.323221          0.383474
# ...              ...          ...               ...
# 26703          53410     0.319443          0.436826
# 26704          53411     0.184929          0.286915
# 26705          53412     0.092017          0.180717
# 26706          53413     0.035595          0.397526
# 26707          53414     0.449643          0.594696
#
# [26708 rows x 3 columns])
# https://github.com/HARSHITH-MANDLI/M.V.S.Harshith_Datahack: ('1 valid CSV files found in the repository',        respondent_id  xyz_vaccine  seasonal_vaccine
# 0              26707     0.383010          0.272421
# 1              26708     0.096686          0.043102
# 2              26709     0.488963          0.729557
# 3              26710     0.876236          0.887549
# 4              26711     0.654207          0.485935
# ...              ...          ...               ...
# 26703          53410     0.663501          0.510742
# 26704          53411     0.452931          0.310502
# 26705          53412     0.364901          0.195418
# 26706          53413     0.041421          0.333060
# 26707          53414     0.737926          0.668301
#
# [26708 rows x 3 columns])
# https://github.com/Anushika0601/Anushika_Srivastava_DataHack: ('1 valid CSV files found in the repository',        respondent_id  h1n1_vaccine  seasonal_vaccine
# 0              26707      0.137401          0.449521
# 1              26708      0.050541          0.104631
# 2              26709      0.273533          0.497736
# 3              26710      0.427290          0.768422
# 4              26711      0.276080          0.621323
# ...              ...           ...               ...
# 26703          53410      0.340830          0.552415
# 26704          53411      0.055840          0.309190
# 26705          53412      0.198220          0.390897
# 26706          53413      0.052385          0.319695
# 26707          53414      0.584844          0.653198
#
# [26708 rows x 3 columns])
# https://github.com/madhu04075/Datahack_1.git: ('1 valid CSV files found in the repository',        respondent_id  h1n1_vaccine  seasonal_vaccine
# 0              26707      0.921477          0.078523
# 1              26708      0.942976          0.057024
# 2              26709      0.606660          0.393340
# 3              26710      0.472126          0.527874
# 4              26711      0.792150          0.207850
# ...              ...           ...               ...
# 26703          53410      0.648315          0.351685
# 26704          53411      0.912673          0.087327
# 26705          53412      0.824665          0.175335
# 26706          53413      0.921799          0.078201
# 26707          53414      0.459692          0.540308
#
# [26708 rows x 3 columns])
# https://github.com/Manas8953/Project: No valid CSV file found in the repository
# https://github.com/swatiswapna/swati_swapna_Datahack.git: ('1 valid CSV files found in the repository',        respondent_id  h1n1_vaccine  seasonal_vaccine
# 0              26707          0.10              0.41
# 1              26708          0.04              0.08
# 2              26709          0.52              0.81
# 3              26710          0.54              0.85
# 4              26711          0.29              0.46
# ...              ...           ...               ...
# 26703          53410          0.26              0.58
# 26704          53411          0.14              0.27
# 26705          53412          0.07              0.30
# 26706          53413          0.06              0.37
# 26707          53414          0.41              0.65
#
# [26708 rows x 3 columns])
# https://github.com/suchiagarwal23/Suchi_Agarwal_Datahack: ('1 valid CSV files found in the repository',        respondent_id  xyz_vaccine  seasonal_vaccine
# 0              26707     0.087491          0.273279
# 1              26708     0.044884          0.044545
# 2              26709     0.445624          0.689806
# 3              26710     0.485274          0.881442
# 4              26711     0.228202          0.506247
# ...              ...          ...               ...
# 26703          53410     0.331554          0.536969
# 26704          53411     0.074562          0.205708
# 26705          53412     0.135897          0.217501
# 26706          53413     0.056120          0.439434
# 26707          53414     0.553008          0.576146
#
# [26708 rows x 3 columns])
# https://github.com/svunofficial/Shivashish_DataHack.git: ('1 valid CSV files found in the repository',        respondent_id  xyz_vaccine  seasonal_vaccine
# 0              26707     0.083018          0.182995
# 1              26708     0.045264          0.041221
# 2              26709     0.470053          0.651138
# 3              26710     0.463651          0.903381
# 4              26711     0.183584          0.595468
# ...              ...          ...               ...
# 26703          53410          NaN               NaN
# 26704          53411     0.065663          0.257544
# 26705          53412     0.117864          0.184747
# 26706          53413     0.053236          0.492974
# 26707          53414          NaN               NaN
#
# [26708 rows x 3 columns])
# Number of repositories that couldn't be accessed: 10
# Number of valid csv files : 134
